# %%
from matplotlib import pyplot as plt

# %%
import numpy as np


total_error = np.linspace(0.001, 0.5, 100)

# %%
# total_error

aos = 0.5 * np.log((1 - total_error) / total_error)

# %%
plt.plot(total_error, aos)
plt.xlabel('Total error')
plt.ylabel('AOS')
# Out:
# Text(0, 0.5, 'AOS')
