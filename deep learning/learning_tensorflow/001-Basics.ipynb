# %% [markdown]
# ### Setup and Load Data

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.5/390.3 MB 882.6 kB/s eta 0:07:22
#    ---------------------------------------- 0.8/390.3 MB 931.2 kB/s eta 0:06:59
#    ---------------------------------------- 1.0/390.3 MB 1.0 MB/s eta 0:06:28
#    ---------------------------------------- 1.3/390.3 MB 932.1 kB/s eta 0:06:58
#    ---------------------------------------- 1.3/390.3 MB 932.1 kB/s eta 0:06:58
#    ---------------------------------------- 1.3/390.3 MB 932.1 kB/s eta 0:06:58
# ...

# %%
import tensorflow as tf
import os

# %%
# Creating Essential Path as Constants
HAPPY_DIR = os.path.join('data', 'happy')
HAPPY_DIR = os.path.join('data', 'sad')

# %% [markdown]
# ### Remove Dodgy Images

# %% [markdown]
# ### Load Data
